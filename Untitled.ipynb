# %%
import datetime
import twitch_to_mongo
from pymongo import MongoClient

client = MongoClient("mongodb+srv://read-only:EzWvxGgSDOIX2T9o@cluster0.chzpe.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
db.twitch.find_one()
# Out:
# {'_id': ObjectId('613bc315265fe6c84feb8ea9'),
#  'id': '43212838700',
#  'user_id': '71588578',
#  'user_login': 'therealknossi',
#  'user_name': 'TheRealKnossi',
#  'game_id': '509663',
#  'game_name': 'Special Events',
#  'type': 'live',
#  'title': 'ANGELCAMP 2 mit Knossi, Sido, MannyMarc und UnsympathischTV ',
#  'viewer_count': 133202,
#  'started_at': datetime.datetime(2021, 9, 9, 15, 2, 32),
#  'language': 'de',
#  'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_therealknossi-{width}x{height}.jpg',
#  'tag_ids': ['9166ad14-41f1-4b04-a3b8-c8eb838c6be6'],
#  'is_mature': True,
#  'date': datetime.datetime(2021, 9, 10, 20, 41, 54, 764000)}

# %%
from apscheduler.schedulers.background import BackgroundScheduler

sched = BackgroundScheduler(daemon=True)


sched.add_job(lambda : sched.print_jobs(),'interval',seconds=5)

sched.start()
# Out:
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:41:47 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:41:52 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:41:57 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:42:02 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:42:07 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:42:12 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:42:17 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:42:22 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:42:27 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:42:32 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:42:37 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:42:42 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:42:47 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:42:52 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:42:57 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:43:02 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:43:07 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:43:12 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:43:17 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:43:22 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:43:27 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:43:32 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:43:37 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:43:42 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:43:47 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:43:52 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:43:57 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:44:02 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:44:07 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:44:12 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:44:17 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:44:22 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:44:27 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:44:32 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:44:37 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:44:42 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:44:47 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:44:52 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:44:57 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:45:02 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:45:07 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:45:12 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:45:17 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:45:22 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:45:27 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:45:32 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:45:37 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:45:42 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:45:47 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:45:52 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:45:57 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:46:02 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:46:07 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:46:12 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:46:17 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:46:22 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:46:27 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:46:32 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:46:37 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:46:42 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:46:47 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:46:52 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:46:57 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:47:02 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:47:07 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:47:12 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:47:17 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:47:22 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:47:27 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:47:32 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:47:37 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:47:42 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:47:47 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:47:52 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:47:57 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:48:02 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:48:07 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:48:12 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:48:17 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:48:22 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:48:27 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:48:32 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:48:37 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:48:42 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:48:47 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:48:52 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:48:57 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:49:02 BST)
# Jobstore default:
#     <lambda> (trigger: interval[0:00:05], next run at: 2021-09-10 23:49:07 BST)

# %%
sched.shutdown()

# %%
# %pip install apscheduler
# Out:
# WARNING: Ignoring invalid distribution -penpyn (/Users/matteofortier/opt/anaconda3/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -penpyn (/Users/matteofortier/opt/anaconda3/lib/python3.8/site-packages)
# Requirement already satisfied: apscheduler in /Users/matteofortier/opt/anaconda3/lib/python3.8/site-packages (3.7.0)
# Requirement already satisfied: six>=1.4.0 in /Users/matteofortier/opt/anaconda3/lib/python3.8/site-packages (from apscheduler) (1.15.0)
# Requirement already satisfied: tzlocal~=2.0 in /Users/matteofortier/opt/anaconda3/lib/python3.8/site-packages (from apscheduler) (2.1)
# Requirement already satisfied: setuptools>=0.7 in /Users/matteofortier/opt/anaconda3/lib/python3.8/site-packages (from apscheduler) (57.4.0)
# Requirement already satisfied: pytz in /Users/matteofortier/opt/anaconda3/lib/python3.8/site-packages (from apscheduler) (2021.1)
# WARNING: Ignoring invalid distribution -penpyn (/Users/matteofortier/opt/anaconda3/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -penpyn (/Users/matteofortier/opt/anaconda3/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -penpyn (/Users/matteofortier/opt/anaconda3/lib/python3.8/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %python twitch_autoscheduler.py
# Out:
# UsageError: Line magic function `%python` not found (But cell magic `%%python` exists, did you mean that instead?).
